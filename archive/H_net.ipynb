# %% [markdown]
# Here comes HNet into play which uses statistical tests to determine the significant relationships across variables.
# Our dataset contains only continuous values it should follow a different method, think of methods such as PCA, t-SNE, SVD, UMAP. See references for more information and notebook examples [3

# %%
# Import HNet library
from hnet import hnet

# Initialize with default settings
hn = hnet()

# Initialize and set user specific parameters
hn = hnet(alpha=0.05, y_min=10, perc_min_num=0.8, multtest='holm', dtypes='pandas')

# Import Titanic dataset
df = hn.import_example('titanic')

# Print to screen
print(df)
# Out:
# [hnet] >Downloading [titanic] dataset from github source..
# [hnet] >Import dataset [titanic]
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
results = hn.association_learning(df)
# Out:
# [df2onehot] >Auto detecting dtypes.
# 100%|██████████| 12/12 [00:00<00:00, 138.01it/s]
# [df2onehot] >Set dtypes in dataframe..
# 100%|██████████| 12/12 [00:00<00:00, 280.02it/s]
# [df2onehot] >Total onehot features: 19
# [hnet] >Association learning across [19] categories.
# 100%|██████████| 19/19 [00:06<00:00,  3.08it/s]
# [hnet] >Multiple test correction using holm
# [hnet] >Dropping PassengerId
# [hnet] >Dropping Age
# [hnet] >Dropping Fare
# ----------------------------------------------------
# [hnet] >Total number of associatons computed: [2162]
# ----------------------------------------------------
# [hnet] >Computing category association using fishers method..
# 100%|██████████| 10/10 [00:00<00:00, 218.15it/s]
# [hnet] >Fin.

# %%
# Make static network plot
G1 = hn.plot()

# Make static heatmap
G2 = hn.heatmap()
# Out:
# [hnet] >Building static network graph..
# [hnet] >Building static heatmap.

# %%
# Plot summarized heatmap
hn.heatmap(summarize=True, cluster=True)
hn.d3heatmap(summarize=True)

# Plot summarized static graph
hn.plot(summarize=True)
hn.d3graph(summarize=True, charge=1000)
# Out:
# [hnet] >Building static heatmap.
# [hnet] >Building dynamic heatmaps using d3graph..
# [hnet] >Building static network graph..
# [hnet] >Clustering using best partition
# [hnet] >Creating output html..
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13353/3910591454.py in <module>
#       1 # Plot summarized heatmap
#       2 hn.heatmap(summarize=True, cluster=True)
# ----> 3 hn.d3heatmap(summarize=True)
#       4
#       5 # Plot summarized static graph
#
# ~/.local/share/virtualenvs/CARLA-7s4zdYsf/lib/python3.7/site-packages/hnet/hnet.py in d3heatmap(self, summarize, savepath, directed, threshold, white_list, black_list, min_edges, figsize, vmax, showfig, verbose)
#     434         # Make heatmap
#     435         if verbose>=3: print('[hnet] >Creating output html..')
# ...
